# %% [markdown]
# # Compliance Data  -- Monthly Report

# %%
import pandas as pd
import numpy as np

# %%
###Import data
##1. Find file in finder
##2. Option + Command + C
##3. Paste Info read_csv(r” ”)

#Data file merges with All Dates when all data is saved from Access. When saved from SQL, the data does not merge accurately.

df = pd.ExcelFile(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data v3 ACCESS.xlsx")

# %%
#Read data from corrrect tab.

ideation = df.parse('Ideation')
acs = df.parse('ACS')
missing = df.parse('MISSING')
inc = df.parse('L1-5')
material = df.parse('Material')
alldates = df.parse('All Dates')

# %%
alldates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        365 non-null    datetime64[ns]
#  1   Day of Week                 365 non-null    object
#  2   School Day                  365 non-null    object
#  3   Nearest School Day          365 non-null    datetime64[ns]
#  4   Final Day to ENTER - 1 Day  365 non-null    datetime64[ns]
#  5   2 Days                      365 non-null    datetime64[ns]
#  6   5 Days                      365 non-null    datetime64[ns]
#  7   10 Days                     365 non-null    datetime64[ns]
# dtypes: datetime64[ns](6), object(2)
# memory usage: 22.9+ KB

# %% [markdown]
# **SUICIDE IDEATION**

# %% [markdown]
# 1. Import Incident Data
# 2. Merge with All Dates -- Join on Data
# 3. Add Final Day to ENTER - 1 Day, 10 Days from All Dates table
# 4. Create field: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO
# 5. Create field: Updated on Time: If Updated Date <= 10 Days --> YES, otherwise, NO
# 6. If Updated Data is Blank, leave Updated on Time Blank.

# %%
#schools_susptype = schools.merge(susptypefinal, left_on='DBN', right_on='ATS', how='left')
ideation_df = ideation.merge(alldates, left_on='Date', right_on='Date', how='left')

# %%
#schools_susptype.drop('ATS', axis = 1, inplace = True)
#Drop Day of Week, School Day, Nearest School Day, 2 Days, 5 Days
ideation_df.drop('Day of Week', axis = 1, inplace = True)
ideation_df.drop('School Day', axis = 1, inplace = True)
ideation_df.drop('Nearest School Day', axis = 1, inplace = True)
ideation_df.drop('2 Days', axis = 1, inplace = True)
ideation_df.drop('5 Days', axis = 1, inplace = True)
ideation_df.drop('UpdatedText', axis = 1, inplace = True)
ideation_df.drop('EventType', axis = 1, inplace = True)

# %%
ideation_df
# Out:
#       RowNumber AcademicYear     ATS  \
# 0             1    2020-2021  15K010
# 1             1    2020-2021  10X565
# 2             1    2020-2021  10X445
# 3             1    2020-2021  10X445
# 4             1    2020-2021  10X046
# ...         ...          ...     ...
# 1412          1    2020-2021  27Q146
# 1413          1    2020-2021  24Q229
# 1414          1    2020-2021  21K215
# 1415          1    2020-2021  09X128
# 1416          1    2020-2021  75X017
#
#                                             School Name           ControlNo  \
# 0     Magnet School of Math, Science and Design Tech...  15K010-091720-0004
# 1                 High School for Energy and Technology  10X565-092120-0005
# 2                          Bronx High School of Science  10X445-092220-0010
# 3                          Bronx High School of Science  10X445-092920-0012
# 4                              P.S. 046 Edgar Allan Poe  10X046-092920-0006
# ...                                                 ...                 ...
# 1412                              P.S. 146 Howard Beach  27Q146-121220-0016
# 1413                            P.S. 229 Emanuel Kaplan  24Q229-011521-0018
# 1414                           P.S. 215 Morris H. Weiss  21K215-011521-0028
# 1415                                      Mott Hall III  09X128-011921-0027
# 1416                                          P.S. X017  75X017-012021-0101
#
#      Code    EIC       Date PrincInformed OccDateEntered Updated Date  \
# 0     O57  False 2020-09-17    2020-09-17     2020-09-17   2020-09-18
# 1     O57  False 2020-09-21    2020-09-22     2020-09-22   2020-09-22
# 2     O57  False 2020-09-22    2020-09-22     2020-09-22   2020-09-23
# 3     O57  False 2020-09-29    2020-09-29     2020-09-29   2020-10-02
# 4     O57  False 2020-09-29    2020-09-29     2020-09-30   2020-10-07
# ...   ...    ...        ...           ...            ...          ...
# 1412  O57  False 2020-12-12    2021-01-13     2021-01-13   2021-01-19
# 1413  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-22
# 1414  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-19
# 1415  O57   True 2021-01-19    2021-01-19     2021-01-20   2021-01-20
# 1416  O57   True 2021-01-20    2021-01-20     2021-01-20   2021-01-20
#
#                 WhoSource Final Day to ENTER - 1 Day    10 Days
# 0         CENTRAL\GOramas                 2020-09-18 2020-10-02
# 1     CENTRAL\VWilliams10                 2020-09-22 2020-10-06
# 2        CENTRAL\DHeckman                 2020-09-23 2020-10-07
# 3        CENTRAL\DHeckman                 2020-09-30 2020-10-14
# 4       CENTRAL\EMaydwell                 2020-09-30 2020-10-14
# ...                   ...                        ...        ...
# 1412     CENTRAL\CBrowne6                 2020-12-14 2021-01-05
# 1413      CENTRAL\EGarrit                 2021-01-19 2021-02-01
# 1414      CENTRAL\NBocchi                 2021-01-19 2021-02-01
# 1415     CENTRAL\SSimmon2                 2021-01-20 2021-02-02
# 1416     CENTRAL\SSimmon2                 2021-01-21 2021-02-03
#
# [1417 rows x 14 columns]

# %%
#Create fileds: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO
#Source: https://www.geeksforgeeks.org/python-creating-a-pandas-dataframe-column-based-on-a-given-condition/
#df['hasimage'] = np.where(df['photos']!= '[]', True, False)  
#Source: https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/
#df['Price'] = [1500 if x =='Music' else 800 for x in df['Event']] 

ideation_df['Entered on Time'] = np.where(ideation_df['OccDateEntered'] <= ideation_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')

# %%
ideation_df
# Out:
#       RowNumber AcademicYear     ATS  \
# 0             1    2020-2021  15K010
# 1             1    2020-2021  10X565
# 2             1    2020-2021  10X445
# 3             1    2020-2021  10X445
# 4             1    2020-2021  10X046
# ...         ...          ...     ...
# 1412          1    2020-2021  27Q146
# 1413          1    2020-2021  24Q229
# 1414          1    2020-2021  21K215
# 1415          1    2020-2021  09X128
# 1416          1    2020-2021  75X017
#
#                                             School Name           ControlNo  \
# 0     Magnet School of Math, Science and Design Tech...  15K010-091720-0004
# 1                 High School for Energy and Technology  10X565-092120-0005
# 2                          Bronx High School of Science  10X445-092220-0010
# 3                          Bronx High School of Science  10X445-092920-0012
# 4                              P.S. 046 Edgar Allan Poe  10X046-092920-0006
# ...                                                 ...                 ...
# 1412                              P.S. 146 Howard Beach  27Q146-121220-0016
# 1413                            P.S. 229 Emanuel Kaplan  24Q229-011521-0018
# 1414                           P.S. 215 Morris H. Weiss  21K215-011521-0028
# 1415                                      Mott Hall III  09X128-011921-0027
# 1416                                          P.S. X017  75X017-012021-0101
#
#      Code    EIC       Date PrincInformed OccDateEntered Updated Date  \
# 0     O57  False 2020-09-17    2020-09-17     2020-09-17   2020-09-18
# 1     O57  False 2020-09-21    2020-09-22     2020-09-22   2020-09-22
# 2     O57  False 2020-09-22    2020-09-22     2020-09-22   2020-09-23
# 3     O57  False 2020-09-29    2020-09-29     2020-09-29   2020-10-02
# 4     O57  False 2020-09-29    2020-09-29     2020-09-30   2020-10-07
# ...   ...    ...        ...           ...            ...          ...
# 1412  O57  False 2020-12-12    2021-01-13     2021-01-13   2021-01-19
# 1413  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-22
# 1414  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-19
# 1415  O57   True 2021-01-19    2021-01-19     2021-01-20   2021-01-20
# 1416  O57   True 2021-01-20    2021-01-20     2021-01-20   2021-01-20
#
#                 WhoSource Final Day to ENTER - 1 Day    10 Days  \
# 0         CENTRAL\GOramas                 2020-09-18 2020-10-02
# 1     CENTRAL\VWilliams10                 2020-09-22 2020-10-06
# 2        CENTRAL\DHeckman                 2020-09-23 2020-10-07
# 3        CENTRAL\DHeckman                 2020-09-30 2020-10-14
# 4       CENTRAL\EMaydwell                 2020-09-30 2020-10-14
# ...                   ...                        ...        ...
# 1412     CENTRAL\CBrowne6                 2020-12-14 2021-01-05
# 1413      CENTRAL\EGarrit                 2021-01-19 2021-02-01
# 1414      CENTRAL\NBocchi                 2021-01-19 2021-02-01
# 1415     CENTRAL\SSimmon2                 2021-01-20 2021-02-02
# 1416     CENTRAL\SSimmon2                 2021-01-21 2021-02-03
#
#      Entered on Time
# 0                YES
# 1                YES
# 2                YES
# 3                YES
# 4                YES
# ...              ...
# 1412              NO
# 1413             YES
# 1414             YES
# 1415             YES
# 1416             YES
#
# [1417 rows x 15 columns]

# %%
ideation_df['Updated on Time'] = np.where(ideation_df['Updated Date'] <= ideation_df['10 Days'], 'YES', 'NO')

# %%
ideation_df
# Out:
#       RowNumber AcademicYear     ATS  \
# 0             1    2020-2021  15K010
# 1             1    2020-2021  10X565
# 2             1    2020-2021  10X445
# 3             1    2020-2021  10X445
# 4             1    2020-2021  10X046
# ...         ...          ...     ...
# 1412          1    2020-2021  27Q146
# 1413          1    2020-2021  24Q229
# 1414          1    2020-2021  21K215
# 1415          1    2020-2021  09X128
# 1416          1    2020-2021  75X017
#
#                                             School Name           ControlNo  \
# 0     Magnet School of Math, Science and Design Tech...  15K010-091720-0004
# 1                 High School for Energy and Technology  10X565-092120-0005
# 2                          Bronx High School of Science  10X445-092220-0010
# 3                          Bronx High School of Science  10X445-092920-0012
# 4                              P.S. 046 Edgar Allan Poe  10X046-092920-0006
# ...                                                 ...                 ...
# 1412                              P.S. 146 Howard Beach  27Q146-121220-0016
# 1413                            P.S. 229 Emanuel Kaplan  24Q229-011521-0018
# 1414                           P.S. 215 Morris H. Weiss  21K215-011521-0028
# 1415                                      Mott Hall III  09X128-011921-0027
# 1416                                          P.S. X017  75X017-012021-0101
#
#      Code    EIC       Date PrincInformed OccDateEntered Updated Date  \
# 0     O57  False 2020-09-17    2020-09-17     2020-09-17   2020-09-18
# 1     O57  False 2020-09-21    2020-09-22     2020-09-22   2020-09-22
# 2     O57  False 2020-09-22    2020-09-22     2020-09-22   2020-09-23
# 3     O57  False 2020-09-29    2020-09-29     2020-09-29   2020-10-02
# 4     O57  False 2020-09-29    2020-09-29     2020-09-30   2020-10-07
# ...   ...    ...        ...           ...            ...          ...
# 1412  O57  False 2020-12-12    2021-01-13     2021-01-13   2021-01-19
# 1413  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-22
# 1414  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-19
# 1415  O57   True 2021-01-19    2021-01-19     2021-01-20   2021-01-20
# 1416  O57   True 2021-01-20    2021-01-20     2021-01-20   2021-01-20
#
#                 WhoSource Final Day to ENTER - 1 Day    10 Days  \
# 0         CENTRAL\GOramas                 2020-09-18 2020-10-02
# 1     CENTRAL\VWilliams10                 2020-09-22 2020-10-06
# 2        CENTRAL\DHeckman                 2020-09-23 2020-10-07
# 3        CENTRAL\DHeckman                 2020-09-30 2020-10-14
# 4       CENTRAL\EMaydwell                 2020-09-30 2020-10-14
# ...                   ...                        ...        ...
# 1412     CENTRAL\CBrowne6                 2020-12-14 2021-01-05
# 1413      CENTRAL\EGarrit                 2021-01-19 2021-02-01
# 1414      CENTRAL\NBocchi                 2021-01-19 2021-02-01
# 1415     CENTRAL\SSimmon2                 2021-01-20 2021-02-02
# 1416     CENTRAL\SSimmon2                 2021-01-21 2021-02-03
#
#      Entered on Time Updated on Time
# 0                YES             YES
# 1                YES             YES
# 2                YES             YES
# 3                YES             YES
# 4                YES             YES
# ...              ...             ...
# 1412              NO              NO
# 1413             YES             YES
# 1414             YES             YES
# 1415             YES             YES
# 1416             YES             YES
#
# [1417 rows x 16 columns]

# %%
#Updated on Time: If Updated Date <= 10 Days --> YES, otherwise, NO
#ideation_df['Entered on Time'] = np.where(ideation_df['OccDateEntered'] <= ideation_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')
ideation_df['Updated on Time'] = np.where(ideation_df['Updated Date'].isnull(), ' ', ideation_df['Updated on Time'])

# %%
ideation_df
# Out:
#       RowNumber AcademicYear     ATS  \
# 0             1    2020-2021  15K010
# 1             1    2020-2021  10X565
# 2             1    2020-2021  10X445
# 3             1    2020-2021  10X445
# 4             1    2020-2021  10X046
# ...         ...          ...     ...
# 1412          1    2020-2021  27Q146
# 1413          1    2020-2021  24Q229
# 1414          1    2020-2021  21K215
# 1415          1    2020-2021  09X128
# 1416          1    2020-2021  75X017
#
#                                             School Name           ControlNo  \
# 0     Magnet School of Math, Science and Design Tech...  15K010-091720-0004
# 1                 High School for Energy and Technology  10X565-092120-0005
# 2                          Bronx High School of Science  10X445-092220-0010
# 3                          Bronx High School of Science  10X445-092920-0012
# 4                              P.S. 046 Edgar Allan Poe  10X046-092920-0006
# ...                                                 ...                 ...
# 1412                              P.S. 146 Howard Beach  27Q146-121220-0016
# 1413                            P.S. 229 Emanuel Kaplan  24Q229-011521-0018
# 1414                           P.S. 215 Morris H. Weiss  21K215-011521-0028
# 1415                                      Mott Hall III  09X128-011921-0027
# 1416                                          P.S. X017  75X017-012021-0101
#
#      Code    EIC       Date PrincInformed OccDateEntered Updated Date  \
# 0     O57  False 2020-09-17    2020-09-17     2020-09-17   2020-09-18
# 1     O57  False 2020-09-21    2020-09-22     2020-09-22   2020-09-22
# 2     O57  False 2020-09-22    2020-09-22     2020-09-22   2020-09-23
# 3     O57  False 2020-09-29    2020-09-29     2020-09-29   2020-10-02
# 4     O57  False 2020-09-29    2020-09-29     2020-09-30   2020-10-07
# ...   ...    ...        ...           ...            ...          ...
# 1412  O57  False 2020-12-12    2021-01-13     2021-01-13   2021-01-19
# 1413  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-22
# 1414  O57  False 2021-01-15    2021-01-15     2021-01-15   2021-01-19
# 1415  O57   True 2021-01-19    2021-01-19     2021-01-20   2021-01-20
# 1416  O57   True 2021-01-20    2021-01-20     2021-01-20   2021-01-20
#
#                 WhoSource Final Day to ENTER - 1 Day    10 Days  \
# 0         CENTRAL\GOramas                 2020-09-18 2020-10-02
# 1     CENTRAL\VWilliams10                 2020-09-22 2020-10-06
# 2        CENTRAL\DHeckman                 2020-09-23 2020-10-07
# 3        CENTRAL\DHeckman                 2020-09-30 2020-10-14
# 4       CENTRAL\EMaydwell                 2020-09-30 2020-10-14
# ...                   ...                        ...        ...
# 1412     CENTRAL\CBrowne6                 2020-12-14 2021-01-05
# 1413      CENTRAL\EGarrit                 2021-01-19 2021-02-01
# 1414      CENTRAL\NBocchi                 2021-01-19 2021-02-01
# 1415     CENTRAL\SSimmon2                 2021-01-20 2021-02-02
# 1416     CENTRAL\SSimmon2                 2021-01-21 2021-02-03
#
#      Entered on Time Updated on Time
# 0                YES             YES
# 1                YES             YES
# 2                YES             YES
# 3                YES             YES
# 4                YES             YES
# ...              ...             ...
# 1412              NO              NO
# 1413             YES             YES
# 1414             YES             YES
# 1415             YES             YES
# 1416             YES             YES
#
# [1417 rows x 16 columns]

# %%
#Export data to excel: https://datatofish.com/export-dataframe-to-excel/
#df.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)
#Formatting: https://xlsxwriter.readthedocs.io/working_with_pandas.html

#ideation_df.to_excel(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx", sheet_name='Ideation',header=True, merge_cells=False, index=False)

# %% [markdown]
# **ACS**

# %% [markdown]
# 1. Import ACS Data
# 2. Merge with All Dates -- Join on Date
# 3. Add Final Day to ENTER - 1 Day, 10 Days from All Dates table
# 4. Create field: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO

# %%
acs_df = acs.merge(alldates, left_on='Date', right_on='Date', how='left')

# %%
acs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2803 entries, 0 to 2802
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DBN                         2803 non-null   object
#  1   School Name                 2803 non-null   object
#  2   Code                        2803 non-null   object
#  3   EIC                         2803 non-null   bool
#  4   OORS#                       2803 non-null   object
#  5   Date                        2803 non-null   datetime64[ns]
#  6   PrincInformed               2803 non-null   datetime64[ns]
#  7   OccDateEntered              2803 non-null   datetime64[ns]
#  8   Academic Year               2803 non-null   object
#  9   PreparedBy                  2803 non-null   object
#  10  PreparedByEmail             2292 non-null   object
#  11  WhoSource                   2803 non-null   object
#  12  EventType                   2803 non-null   object
#  13  Unnamed: 13                 7 non-null      object
#  14  Day of Week                 2803 non-null   object
#  15  School Day                  2803 non-null   object
#  16  Nearest School Day          2803 non-null   datetime64[ns]
#  17  Final Day to ENTER - 1 Day  2803 non-null   datetime64[ns]
#  18  2 Days                      2803 non-null   datetime64[ns]
#  19  5 Days                      2803 non-null   datetime64[ns]
#  20  10 Days                     2803 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns](8), object(12)
# memory usage: 462.6+ KB

# %%
acs_df.tail()
# Out:
#          DBN                     School Name Code    EIC               OORS#  \
# 2798  08X152              P.S. 152 Evergreen  O77  False  08X152-012121-0027
# 2799  12X150      P.S. 150 Charles James Fox  O77  False  12X150-012121-0018
# 2800  11X076  P.S. 076 The Bennington School  O77  False  11X076-012121-0048
# 2801  27Q183   P.S. 183 Dr. Richard R. Green  O77  False  27Q183-012121-0021
# 2802  75K811   P.S. K811 Connie Lekas School  O77  False  75K811-012121-0011
#
#            Date PrincInformed OccDateEntered Academic Year  \
# 2798 2021-01-21    2021-01-21     2021-01-21     2020-2021
# 2799 2021-01-21    2021-01-21     2021-01-21     2020-2021
# 2800 2021-01-21    2021-01-21     2021-01-21     2020-2021
# 2801 2021-01-21    2021-01-21     2021-01-21     2020-2021
# 2802 2021-01-21    2021-01-21     2021-01-21     2020-2021
#
#                   PreparedBy  ...                WhoSource EventType  \
# 2798             Angela Vera  ...           CENTRAL\AVera2   Entered
# 2799  Ms. Kelly Padilla LCSW  ...          CENTRAL\kpadill   Entered
# 2800       Micaela Tomasetti  ...       CENTRAL\MTomasetti   Entered
# 2801          Rhea Peykarian  ...       CENTRAL\RPeykarian   Entered
# 2802       A Waterman French  ...  CENTRAL\AWatermanFrench   Entered
#
#      Unnamed: 13 Day of Week School Day Nearest School Day  \
# 2798         NaN    Thursday        Yes         2021-01-21
# 2799         NaN    Thursday        Yes         2021-01-21
# 2800         NaN    Thursday        Yes         2021-01-21
# 2801         NaN    Thursday        Yes         2021-01-21
# 2802         NaN    Thursday        Yes         2021-01-21
#
#      Final Day to ENTER - 1 Day     2 Days     5 Days    10 Days
# 2798                 2021-01-22 2021-01-25 2021-01-28 2021-02-04
# 2799                 2021-01-22 2021-01-25 2021-01-28 2021-02-04
# 2800                 2021-01-22 2021-01-25 2021-01-28 2021-02-04
# 2801                 2021-01-22 2021-01-25 2021-01-28 2021-02-04
# 2802                 2021-01-22 2021-01-25 2021-01-28 2021-02-04
#
# [5 rows x 21 columns]

# %%
#Drop Day of Week, School Day, Nearest School Day, 2 Days, 5 Days
acs_df.drop('Code', axis = 1, inplace = True)
acs_df.drop('EIC', axis = 1, inplace = True)
acs_df.drop('Academic Year', axis = 1, inplace = True)
acs_df.drop('EventType', axis = 1, inplace = True)
acs_df.drop('Day of Week', axis = 1, inplace = True)
acs_df.drop('School Day', axis = 1, inplace = True)
acs_df.drop('Nearest School Day', axis = 1, inplace = True)
acs_df.drop('2 Days', axis = 1, inplace = True)
acs_df.drop('5 Days', axis = 1, inplace = True)
acs_df.drop('10 Days', axis = 1, inplace = True)
acs_df.drop('Unnamed: 13', axis = 1, inplace = True)

# %%
acs_df.head()
# Out:
#       DBN                                  School Name               OORS#  \
# 0  75Q009                                     P.S. 009  75Q009-070120-0001
# 1  02M298                             Pace High School  02M298-070220-0001
# 2  06M468  High School for Health Careers and Sciences  06M468-070220-0001
# 3  31R455                      Tottenville High School  31R455-070420-0001
# 4  31R455                      Tottenville High School  31R455-070420-0002
#
#         Date PrincInformed OccDateEntered        PreparedBy  \
# 0 2020-07-01    2020-07-01     2020-07-01  John Gonzalez AP
# 1 2020-07-02    2020-07-02     2020-07-02        ERIC GLATZ
# 2 2020-07-02    2020-07-02     2020-07-02      Javier Trejo
# 3 2020-07-04    2020-07-06     2020-07-06        D Pugliese
# 4 2020-07-04    2020-07-06     2020-07-06         D Jackson
#
#             PreparedByEmail         WhoSource Final Day to ENTER - 1 Day
# 0  jgonzal5@schools.nyc.gov  CENTRAL\JGonzal5                 2020-07-02
# 1    eglatz@schools.nyc.gov    CENTRAL\EGlatz                 2020-07-06
# 2    JTrejo@schools.nyc.gov    CENTRAL\JTrejo                 2020-07-06
# 3                       NaN   CENTRAL\GPaglia                 2020-07-06
# 4                       NaN   CENTRAL\GPaglia                 2020-07-06

# %%
acs_df['Entered on Time'] = np.where(acs_df['OccDateEntered'] <= acs_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')

# %%
acs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2803 entries, 0 to 2802
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DBN                         2803 non-null   object
#  1   School Name                 2803 non-null   object
#  2   OORS#                       2803 non-null   object
#  3   Date                        2803 non-null   datetime64[ns]
#  4   PrincInformed               2803 non-null   datetime64[ns]
#  5   OccDateEntered              2803 non-null   datetime64[ns]
#  6   PreparedBy                  2803 non-null   object
#  7   PreparedByEmail             2292 non-null   object
#  8   WhoSource                   2803 non-null   object
#  9   Final Day to ENTER - 1 Day  2803 non-null   datetime64[ns]
#  10  Entered on Time             2803 non-null   object
# dtypes: datetime64[ns](4), object(7)
# memory usage: 262.8+ KB

# %%
#Export data to excel: https://datatofish.com/export-dataframe-to-excel/
#df.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)
#Formatting: https://xlsxwriter.readthedocs.io/working_with_pandas.html

#acs_df.to_excel(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx", sheet_name='ACS',header=True, merge_cells=False, index=False)

# %% [markdown]
# **L1-5 INCIDENTS**

# %% [markdown]
# 1. Import L1-5 Incident Data
# 2. Merge with All Dates -- Join on Date
# 3. Add Final Day to ENTER - 1 Day, 10 Days from All Dates table
# 4. Create field: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO

# %%
inc_df = inc.merge(alldates, left_on='Date', right_on='Date', how='left')

# %%
inc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4416 entries, 0 to 4415
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DBN                         4416 non-null   object
#  1   School Name                 4416 non-null   object
#  2   Level                       4416 non-null   int64
#  3   Code                        4416 non-null   object
#  4   Short Description           4416 non-null   object
#  5   OORS#                       4416 non-null   object
#  6   Date                        4416 non-null   datetime64[ns]
#  7   PrincInformed               4416 non-null   datetime64[ns]
#  8   OccDateEntered              4416 non-null   datetime64[ns]
#  9   Academic Year               4416 non-null   object
#  10  PreparedBy                  4415 non-null   object
#  11  PreparedByEmail             3551 non-null   object
#  12  Location                    4416 non-null   object
#  13  OccID                       4416 non-null   int64
#  14  WhoSource                   4416 non-null   object
#  15  Unnamed: 15                 31 non-null     object
#  16  Day of Week                 4416 non-null   object
#  17  School Day                  4416 non-null   object
#  18  Nearest School Day          4416 non-null   datetime64[ns]
#  19  Final Day to ENTER - 1 Day  4416 non-null   datetime64[ns]
#  20  2 Days                      4416 non-null   datetime64[ns]
#  21  5 Days                      4416 non-null   datetime64[ns]
#  22  10 Days                     4416 non-null   datetime64[ns]
# dtypes: datetime64[ns](8), int64(2), object(13)
# memory usage: 828.0+ KB

# %%
inc_df['Entered on Time'] = np.where(inc_df['OccDateEntered'] <= inc_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')

# %%
#Drop Day of Week, School Day, Nearest School Day, 2 Days, 5 Days

inc_df.drop('Academic Year', axis = 1, inplace = True)
inc_df.drop('PreparedBy', axis = 1, inplace = True)
inc_df.drop('PreparedByEmail', axis = 1, inplace = True)
inc_df.drop('OccID', axis = 1, inplace = True)
inc_df.drop('Day of Week', axis = 1, inplace = True)
inc_df.drop('School Day', axis = 1, inplace = True)
inc_df.drop('Nearest School Day', axis = 1, inplace = True)
inc_df.drop('2 Days', axis = 1, inplace = True)
inc_df.drop('5 Days', axis = 1, inplace = True)
inc_df.drop('10 Days', axis = 1, inplace = True)
inc_df.drop('Unnamed: 15', axis = 1, inplace = True)

# %%
inc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4416 entries, 0 to 4415
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DBN                         4416 non-null   object
#  1   School Name                 4416 non-null   object
#  2   Level                       4416 non-null   int64
#  3   Code                        4416 non-null   object
#  4   Short Description           4416 non-null   object
#  5   OORS#                       4416 non-null   object
#  6   Date                        4416 non-null   datetime64[ns]
#  7   PrincInformed               4416 non-null   datetime64[ns]
#  8   OccDateEntered              4416 non-null   datetime64[ns]
#  9   Location                    4416 non-null   object
#  10  WhoSource                   4416 non-null   object
#  11  Final Day to ENTER - 1 Day  4416 non-null   datetime64[ns]
#  12  Entered on Time             4416 non-null   object
# dtypes: datetime64[ns](4), int64(1), object(8)
# memory usage: 483.0+ KB

# %%
#Export data to excel: https://datatofish.com/export-dataframe-to-excel/
#df.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)
#Formatting: https://xlsxwriter.readthedocs.io/working_with_pandas.html

#inc_df.to_excel(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx", sheet_name='L1-5',header=True, merge_cells=False, index=False)

# %% [markdown]
# **MISSING STUDENTS**

# %% [markdown]
# 1. Import Missing Incident Data
# 2. Merge with All Dates -- Join on Date
# 3. Remove duplicate records based on ControlNo
# 4. Add Final Day to ENTER - 1 Day, 10 Days from All Dates table
# 5. Create field: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO

# %%
missing_df = missing.merge(alldates, left_on='Date', right_on='Date', how='left')

# %%
missing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RowNumber                   54 non-null     int64
#  1   DBN                         54 non-null     object
#  2   School Name                 54 non-null     object
#  3   Academic Year               54 non-null     object
#  4   AcademicYear                54 non-null     object
#  5   ControlNo                   54 non-null     object
#  6   ClassificationCode          54 non-null     object
#  7   Short Description           54 non-null     object
#  8   Date                        54 non-null     datetime64[ns]
#  9   PrincInformed               54 non-null     datetime64[ns]
#  10  OccDateEntered              54 non-null     datetime64[ns]
#  11  Submitted                   54 non-null     bool
#  12  UpdatedDate                 54 non-null     datetime64[ns]
#  13  WhoSource                   54 non-null     object
#  14  Day of Week                 54 non-null     object
#  15  School Day                  54 non-null     object
#  16  Nearest School Day          54 non-null     datetime64[ns]
#  17  Final Day to ENTER - 1 Day  54 non-null     datetime64[ns]
#  18  2 Days                      54 non-null     datetime64[ns]
#  19  5 Days                      54 non-null     datetime64[ns]
#  20  10 Days                     54 non-null     datetime64[ns]
# dtypes: bool(1), datetime64[ns](9), int64(1), object(10)
# memory usage: 8.9+ KB

# %%
#https://www.interviewqs.com/ddi-code-snippets/drop-duplicate-rows-pandas
missing_df = missing_df.drop_duplicates(subset='ControlNo', keep="first")

# %%
missing_df['Entered on Time'] = np.where(missing_df['OccDateEntered'] <= missing_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')

# %%
#Drop Day of Week, School Day, Nearest School Day, 2 Days, 5 Days, 10 Days

missing_df.drop('Submitted', axis = 1, inplace = True)
missing_df.drop('UpdatedDate', axis = 1, inplace = True)
missing_df.drop('Day of Week', axis = 1, inplace = True)
missing_df.drop('School Day', axis = 1, inplace = True)
missing_df.drop('Nearest School Day', axis = 1, inplace = True)
missing_df.drop('2 Days', axis = 1, inplace = True)
missing_df.drop('5 Days', axis = 1, inplace = True)
missing_df.drop('10 Days', axis = 1, inplace = True)

# %%
missing_df.head()
# Out:
#    RowNumber     DBN                            School Name Academic Year  \
# 0          1  07X522  Bronx Design and Construction Academy     2020-2021
# 1          1  79M973                        Restart Academy     2020-2021
# 2          1  79M973                        Restart Academy     2020-2021
# 3          1  79M973                        Restart Academy     2020-2021
# 4          1  75M035                               P.S. 035     2020-2021
#
#   AcademicYear           ControlNo ClassificationCode  \
# 0    2020-2021  07X522-101320-0003                B20
# 1    2020-2021  79M973-100820-0009                N12
# 2    2020-2021  79M973-100820-0010                N12
# 3    2020-2021  79M973-100920-0011                B20
# 4    2020-2021  75M035-100620-0009                B20
#
#                                  Short Description       Date PrincInformed  \
# 0  Leaving Class or School Premises w/o Permission 2020-10-13    2020-10-13
# 1                                    Missing child 2020-10-08    2020-10-14
# 2                                    Missing child 2020-10-08    2020-10-14
# 3  Leaving Class or School Premises w/o Permission 2020-10-09    2020-10-09
# 4  Leaving Class or School Premises w/o Permission 2020-10-06    2020-10-06
#
#   OccDateEntered          WhoSource Final Day to ENTER - 1 Day Entered on Time
# 0     2020-10-13    CENTRAL\TLeonar                 2020-10-14             YES
# 1     2020-10-14  CENTRAL\JDhanpaul                 2020-10-09              NO
# 2     2020-10-14  CENTRAL\JDhanpaul                 2020-10-09              NO
# 3     2020-10-14    CENTRAL\TLeonar                 2020-10-13              NO
# 4     2020-10-14    CENTRAL\RDavid3                 2020-10-07              NO

# %%
missing_df.shape
# Out:
# (43, 14)

# %%
#Export data to excel: https://datatofish.com/export-dataframe-to-excel/
#df.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)
#Formatting: https://xlsxwriter.readthedocs.io/working_with_pandas.html

#missing_df.to_excel(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx", sheet_name='Missing',header=True, merge_cells=False, index=False)

# %% [markdown]
# **MATERIAL INCIDENTS**

# %% [markdown]
# Import Material Incident Incident Data
# 1. Merge with All Dates -- Join on Date
# 2. Add Final Day to ENTER - 1 Day, 5 Days, 10 Days from All Dates table
# 3. Create field: Entered on Time: If OccDateEntered <= Final Day to Enter - 1 Day --> YES, otherwise, NO
# 4. Create field: Updated on Time: If Update Date <= 10 Days --> YES, otherwise, NO
# 5. Create field: Investigated on Time: If CRA832InitialInvestigationCompletionDate <= 5 Days --> YES, otherwise, NO

# %%
material_df = material.merge(alldates, left_on='Date', right_on='Date', how='left')

# %%
material_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1824 entries, 0 to 1823
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   RowNumber                                 1824 non-null   int64
#  1   AcademicYear                              1824 non-null   object
#  2   DBN                                       1824 non-null   object
#  3   School Name                               1824 non-null   object
#  4   Classification_Code                       1824 non-null   object
#  5   Short Description                         1824 non-null   object
#  6   OccID                                     1824 non-null   int64
#  7   OORS#                                     1824 non-null   object
#  8   Date                                      1824 non-null   datetime64[ns]
#  9   PrincInformed                             1824 non-null   datetime64[ns]
#  10  Update Date                               1784 non-null   datetime64[ns]
#  11  CRA832InitialInvestigationCompletionDate  1784 non-null   datetime64[ns]
#  12  BiasRelated                               1824 non-null   bool
#  13  MaterialIncidents                         1824 non-null   bool
#  14  OccDateEntered                            1824 non-null   datetime64[ns]
#  15  Cyberbullying                             1824 non-null   bool
#  16  Harassment_Intimidation_Bullying          1824 non-null   bool
#  17  MaterialSexualInNature                    1824 non-null   bool
#  18  InvolveStudentOnStudentConduct            1824 non-null   bool
#  19  CRA832ConductAViolation                   1824 non-null   bool
#  20  Day of Week                               1824 non-null   object
#  21  School Day                                1824 non-null   object
#  22  Nearest School Day                        1824 non-null   datetime64[ns]
#  23  Final Day to ENTER - 1 Day                1824 non-null   datetime64[ns]
#  24  2 Days                                    1824 non-null   datetime64[ns]
#  25  5 Days                                    1824 non-null   datetime64[ns]
#  26  10 Days                                   1824 non-null   datetime64[ns]
# dtypes: bool(7), datetime64[ns](10), int64(2), object(8)
# memory usage: 311.7+ KB

# %%
material_df['Entered on Time'] = np.where(material_df['OccDateEntered'] <= material_df['Final Day to ENTER - 1 Day'], 'YES', 'NO')

# %%
material_df['Investigated on Time'] = np.where(material_df['CRA832InitialInvestigationCompletionDate'] <= material_df['5 Days'], 'YES', 'NO')

# %%
material_df['Investigated on Time'] = np.where(material_df['CRA832InitialInvestigationCompletionDate'].isnull(), ' ', material_df['Investigated on Time'])

# %%
material_df['Updated on Time'] = np.where(material_df['Update Date'] <= material_df['10 Days'], 'YES', 'NO')

# %%
material_df['Updated on Time'] = np.where(material_df['Update Date'].isnull(), ' ', material_df['Updated on Time'])

# %%
#Drop Day of Week, School Day, Nearest School Day, 2 Days, 5 Days

material_df.drop('OccID', axis = 1, inplace = True)
material_df.drop('Harassment_Intimidation_Bullying', axis = 1, inplace = True)
material_df.drop('MaterialSexualInNature', axis = 1, inplace = True)
material_df.drop('Cyberbullying', axis = 1, inplace = True)
material_df.drop('MaterialIncidents', axis = 1, inplace = True)
material_df.drop('BiasRelated', axis = 1, inplace = True)
material_df.drop('Day of Week', axis = 1, inplace = True)
material_df.drop('School Day', axis = 1, inplace = True)
material_df.drop('Nearest School Day', axis = 1, inplace = True)
material_df.drop('2 Days', axis = 1, inplace = True)

# %%
material_df.head()
# Out:
#    RowNumber AcademicYear     DBN                     School Name  \
# 0          1    2020-2021  26Q067        J.H.S. 067 Louis Pasteur
# 1          1    2020-2021  13K430  Brooklyn Technical High School
# 2          1    2020-2021  31R440            New Dorp High School
# 3          1    2020-2021  02M475          Stuyvesant High School
# 4          1    2020-2021  22K425       James Madison High School
#
#   Classification_Code                                  Short Description  \
# 0                 B23                                 Using Slurs (Bias)
# 1                 B34              Sexually Suggestive (Verbal/Physical)
# 2                 B15      Profane, Obscene, Vulgar Language or Gestures
# 3                 B23                                 Using Slurs (Bias)
# 4                 B35  Posting/Distributing Literature or Material Co...
#
#                 OORS#       Date PrincInformed Update Date  \
# 0  26Q067-071820-0001 2020-07-18    2020-07-21  2020-07-23
# 1  13K430-072820-0004 2020-07-28    2020-08-03  2020-08-12
# 2  31R440-091020-0003 2020-09-10    2020-09-10  2020-09-21
# 3  02M475-091620-0010 2020-09-16    2020-09-16  2020-12-04
# 4  22K425-091620-0002 2020-09-16    2020-09-16  2020-09-18
#
#   CRA832InitialInvestigationCompletionDate OccDateEntered  \
# 0                               2020-07-23     2020-07-23
# 1                               2020-08-12     2020-08-03
# 2                               2020-09-21     2020-09-10
# 3                               2020-12-04     2020-09-16
# 4                               2020-09-18     2020-09-16
#
#    InvolveStudentOnStudentConduct  CRA832ConductAViolation  \
# 0                            True                     True
# 1                            True                     True
# 2                            True                    False
# 3                            True                    False
# 4                            True                    False
#
#   Final Day to ENTER - 1 Day     5 Days    10 Days Entered on Time  \
# 0                 2020-07-20 2020-07-24 2020-08-03              NO
# 1                 2020-07-29 2020-08-05 2020-08-12              NO
# 2                 2020-09-11 2020-09-17 2020-09-24             YES
# 3                 2020-09-17 2020-09-23 2020-10-01             YES
# 4                 2020-09-17 2020-09-23 2020-10-01             YES
#
#   Investigated on Time Updated on Time
# 0                  YES             YES
# 1                   NO             YES
# 2                   NO             YES
# 3                   NO              NO
# 4                  YES             YES

# %%
#Export data to excel: https://datatofish.com/export-dataframe-to-excel/
#df.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)
#Formatting: https://xlsxwriter.readthedocs.io/working_with_pandas.html

#material_df.to_excel(r"/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx", sheet_name='Material',header=True, merge_cells=False, index=False)

# %%
#Source: https://xlsxwriter.readthedocs.io/example_pandas_multiple.html

writer = pd.ExcelWriter('/Users/holly/Desktop/nycdoe/01142021 Compliance Data FINAL.xlsx', engine='xlsxwriter')

ideation_df.to_excel(writer, sheet_name='Ideation')
acs_df.to_excel(writer, sheet_name='ACS')
inc_df.to_excel(writer, sheet_name='L1-5')
missing_df.to_excel(writer, sheet_name='Missing')
material_df.to_excel(writer, sheet_name='Material')

writer.save()
